# %% [markdown]
# # **Phase 1: Early On**
# ---

# %% [markdown]
# #### Import [d_cycle.py](d_cycle.py) and `fredapi`

# %%
import os 
import d_cycle as dc 
from fredapi import Fred


api_key = os.environ.get("FRED_API_KEY")
fred = Fred(api_key=api_key)
# Out:
# 2008 Bubble Start: 2002-01-01
# 2008 Bubble End: 2009-01-01

# %% [markdown]
# ## Identify Start and End Dates of the Cycle
# #### 2008

# %%
p = dc.PLOTTING(frequency='q', start=dc.start_2008, end=dc.end_2008, cycle_lines=True)

# %%
p.plot_debt_to_gdp()

# %%
p.plot_category_debt()

# %%
p.plot_debt_vs_gdp()
