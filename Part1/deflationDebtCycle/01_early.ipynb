# %% [markdown]
# # **Phase 1: Early On**
# ---

# %% [markdown]
# - Debt growth from financing interests that simultaneously increase incomes
# - **Sustainable Growth** while income growth can service growing debts

# %% [markdown]
# #### Import [d_cycle.py](d_cycle.py) and `fredapi`

# %%
import os 
import d_cycle as dc 
from fredapi import Fred


api_key = os.environ.get("FRED_API_KEY")
fred = Fred(api_key=api_key)
# Out:
# 2008 Bubble Start: 2002-01-01
# 2008 Bubble End: 2009-01-01
# 2008 Top Start: 2005-01-01
# 2008 Top End: 2009-01-01

# %% [markdown]
# ## Identify Start and End Dates of the Entire Cycle
# - 2008 Default

# %%
standard_start = dc.start_2008
standard_end = dc.end_2008

#other_start = 'yyyy-mm-dd'
#other_end = 'yyyy-mm-dd'

# %%
p = dc.PLOTTING(frequency='q', start=standard_start, end=standard_end)

# %% [markdown]
# # US Debt to GDP
# ---

# %%
p.plot_debt_to_gdp()

# %% [markdown]
# # Debt by Category
# ---

# %%
p.plot_category_debt()

# %% [markdown]
# # US GDP vs. Debt
# ---

# %%
p.plot_debt_vs_gdp()
